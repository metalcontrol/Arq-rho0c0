# %%
import numpy as np
import itertools
import matplotlib.pyplot as plt
from pyroomacoustics import ShoeBox

def frecuencia_modos(nx, ny, nz, lx, ly, lz, c0=343):
    return (c0 / 2) * np.sqrt((nx / lx) ** 2 + (ny / ly) ** 2 + (nz / lz) ** 2)

def clasificar_modo(nx, ny, nz):
    num_ceros = sum([nx == 0, ny == 0, nz == 0])
    if num_ceros == 2:
        return "Axial"
    elif num_ceros == 1:
        return "Tangencial"
    else:
        return "Oblicuo"

# Dimensiones del recinto en metros
lx, ly, lz = 3, 4, 3.5

modos = itertools.product(range(6), repeat=3)  # Genera combinaciones de (nx, ny, nz)
frecuencias = [(nx, ny, nz, frecuencia_modos(nx, ny, nz, lx, ly, lz)) for nx, ny, nz in modos]
frecuencias = [f for f in frecuencias if f[3] > 0]
frecuencias.sort(key=lambda x: x[3])

# Seleccionar las primeras N frecuencias más bajas
N = 6
modos_seleccionados = frecuencias[:N]

# Crear el recinto utilizando pyroomacoustics
room = ShoeBox([lx, ly, lz])

# Graficar los modos seleccionados
for i, (nx, ny, nz, f) in enumerate(modos_seleccionados, 1):
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111, projection='3d')
    room.plot(ax=ax)
    ax.set_title(f'Modo {i}: {f:.2f} Hz')
    plt.show()
